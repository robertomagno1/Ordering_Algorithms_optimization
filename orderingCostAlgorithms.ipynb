# %%
#relazione costi computazinali algoritmi di ordinamento e ricerca :::


def swap(lst, i, j):
    temp = lst[i]
    lst[i] = lst[j]
    lst[j] = temp

def selection_sort(lst):
    comparisons = 0
    for i in range(len(lst)):
        min_index = i
        for j in range(i + 1, len(lst)):
            comparisons += 1
            if lst[min_index] > lst[j]:
                min_index = j
        swap(lst, i, min_index)
    return comparisons

def insertion_sort(lst):
    comparisons = 0
    for i in range(1, len(lst)):
        key = lst[i]
        j = i - 1
        while j >= 0 and lst[j] > key:
            comparisons += 1
            lst[j + 1] = lst[j]
            j -= 1
        comparisons += 1  # For the last comparison where lst[j] <= key
        lst[j + 1] = key
    return comparisons

def bubble_sort(lst):
    comparisons = 0
    for i in range(len(lst)):
        for j in range(0, len(lst) - i - 1):
            comparisons += 1
            if lst[j] > lst[j + 1]:
                swap(lst, j, j + 1)
    return comparisons

def max_comparisons_selection_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = selection_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons_insertion_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = insertion_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons_bubble_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = bubble_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons(lists_1, lists_2, lists_3):
    max_selection = max_comparisons_selection_sort(lists_1)
    max_insertion = max_comparisons_insertion_sort(lists_2)
    max_bubble = max_comparisons_bubble_sort(lists_3)
    return max(max_selection, max_insertion, max_bubble)

# %%
#relazione costi computazinali algoritmi di ordinamento e ricerca :::


def swap(lst, i, j):
    temp = lst[i]
    lst[i] = lst[j]
    lst[j] = temp

def selection_sort(lst):
    comparisons = 0   #start comparison at 0....
    for i in range(len(lst)):
        min_index = i
        for j in range(i + 1, len(lst)):
            comparisons += 1    #update count
            if lst[min_index] > lst[j]:
                min_index = j
        swap(lst, i, min_index)
    return comparisons     ####return count and comparison  

def insertion_sort(lst):
    comparisons = 0   #set comparison to 0
    for i in range(1, len(lst)):
        key = lst[i]
        j = i - 1
        while j >= 0 and lst[j] > key:
            comparisons += 1     #update comparison ....
            lst[j + 1] = lst[j]
            j -= 1
        comparisons += 1  # For the last comparison where lst[j] <= key
        lst[j + 1] = key
    return comparisons     ### return comparison and count ....

def bubble_sort(lst):
    comparisons = 0     ####  set comparison to 0
    for i in range(len(lst)):
        for j in range(0, len(lst) - i - 1): 
            comparisons += 1    ####update comparison 
            if lst[j] > lst[j + 1]:
                swap(lst, j, j + 1)
    return comparisons    #return comparison , count....

def max_comparisons_selection_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = selection_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons_insertion_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = insertion_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons_bubble_sort(input_list_of_lists):
    max_comparisons = 0
    for lst in input_list_of_lists:
        comparisons = bubble_sort(lst[:])  # Use a copy of the list to avoid in-place sorting
        if comparisons > max_comparisons:
            max_comparisons = comparisons
    return max_comparisons

def max_comparisons(lists_1, lists_2, lists_3):
    max_selection = max_comparisons_selection_sort(lists_1)
    max_insertion = max_comparisons_insertion_sort(lists_2)
    max_bubble = max_comparisons_bubble_sort(lists_3)
    return max(max_selection, max_insertion, max_bubble)
